# %%
import pandas as pd
import numpy as np
from citipy import citipy
from config import wak
import requests
from datetime import datetime

# %%
#Create 2000 random longitude and latitude 
lats = np.random.uniform(-90.00, 90.00, size = 2000)
lngs = np.random.uniform(-180.00, 180.00, size = 2000)

lat_lngs = zip(lats,lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
#Create cities list to store city data
cities=[]

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if city is unique then we add it to the list
    if city not in cities:
        cities.append(city)
#print length of cities
len(cities)
# Out:
# 776

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wak

city_data= []

# %%
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):

    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dingle
# Processing Record 2 of Set 1 | qinhuangdao
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | tawau
# Processing Record 5 of Set 1 | arman
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | pahrump
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | celestun
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | gorom-gorom
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | lodhikheda
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | saint-joseph
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | aswan
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | hutchinson
# Processing Record 31 of Set 1 | scottsbluff
# Processing Record 32 of Set 1 | leua
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | fort nelson
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | ystad
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | omboue
# Processing Record 42 of Set 1 | boddam
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | seydi
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | tiarei
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | kaitangata
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | zhezkazgan
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | caravelas
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | ermelo
# Processing Record 7 of Set 2 | hella
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | evensk
# Processing Record 10 of Set 2 | marawi
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | aykhal
# Processing Record 14 of Set 2 | luwuk
# Processing Record 15 of Set 2 | flinders
# Processing Record 16 of Set 2 | abu zabad
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | hobyo
# Processing Record 21 of Set 2 | lubao
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | sioux lookout
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | norman wells
# Processing Record 27 of Set 2 | leh
# Processing Record 28 of Set 2 | aklavik
# Processing Record 29 of Set 2 | polson
# Processing Record 30 of Set 2 | ampanihy
# Processing Record 31 of Set 2 | yulara
# Processing Record 32 of Set 2 | masyaf
# Processing Record 33 of Set 2 | manokwari
# Processing Record 34 of Set 2 | khatanga
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | ambatofinandrahana
# Processing Record 40 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 41 of Set 2 | half moon bay
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | broken hill
# Processing Record 44 of Set 2 | rafaela
# Processing Record 45 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 2 | barkly west
# Processing Record 47 of Set 2 | egvekinot
# Processing Record 48 of Set 2 | bighapur
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | monmouth
# Processing Record 1 of Set 3 | afonso bezerra
# Processing Record 2 of Set 3 | fairbanks
# Processing Record 3 of Set 3 | bandarbeyla
# Processing Record 4 of Set 3 | sohag
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | berlevag
# Processing Record 7 of Set 3 | kathmandu
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | guerrero negro
# Processing Record 10 of Set 3 | torbay
# Processing Record 11 of Set 3 | laguna
# Processing Record 12 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 3 | ouargaye
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | vila franca do campo
# Processing Record 16 of Set 3 | geraldton
# Processing Record 17 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | tikamgarh
# Processing Record 19 of Set 3 | pangnirtung
# Processing Record 20 of Set 3 | alofi
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | qasigiannguit
# Processing Record 23 of Set 3 | eyl
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | shingu
# Processing Record 28 of Set 3 | poya
# Processing Record 29 of Set 3 | kieta
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | tarko-sale
# Processing Record 32 of Set 3 | fukue
# Processing Record 33 of Set 3 | launceston
# Processing Record 34 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 3 | young
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | birjand
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | patacamaya
# Processing Record 43 of Set 3 | havre-saint-pierre
# Processing Record 44 of Set 3 | hasaki
# Processing Record 45 of Set 3 | mason city
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | namatanai
# Processing Record 48 of Set 3 | creel
# Processing Record 49 of Set 3 | karratha
# Processing Record 50 of Set 3 | san juan pueblo
# Processing Record 1 of Set 4 | ratne
# Processing Record 2 of Set 4 | becej
# Processing Record 3 of Set 4 | isla mujeres
# Processing Record 4 of Set 4 | kindu
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | ponta delgada
# Processing Record 7 of Set 4 | harfleur
# Processing Record 8 of Set 4 | kupang
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | kontagora
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | chumikan
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | maningrida
# Processing Record 17 of Set 4 | yining
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | banda aceh
# Processing Record 20 of Set 4 | rypefjord
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | solnechnyy
# Processing Record 23 of Set 4 | ust-ilimsk
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | key west
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | pochutla
# Processing Record 28 of Set 4 | kachiry
# Processing Record 29 of Set 4 | guantanamo
# Processing Record 30 of Set 4 | turtas
# Processing Record 31 of Set 4 | bozhou
# Processing Record 32 of Set 4 | khasan
# Processing Record 33 of Set 4 | tariba
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | tromso
# Processing Record 36 of Set 4 | saint-leu
# Processing Record 37 of Set 4 | olafsvik
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | phetchabun
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | poum
# Processing Record 43 of Set 4 | vestmanna
# Processing Record 44 of Set 4 | seoul
# Processing Record 45 of Set 4 | kedrovyy
# Processing Record 46 of Set 4 | dongsheng
# Processing Record 47 of Set 4 | narsaq
# Processing Record 48 of Set 4 | svetlogorsk
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | floro
# Processing Record 1 of Set 5 | fasa
# Processing Record 2 of Set 5 | severnoye
# Processing Record 3 of Set 5 | westerland
# Processing Record 4 of Set 5 | kayes
# Processing Record 5 of Set 5 | labrea
# Processing Record 6 of Set 5 | yengema
# Processing Record 7 of Set 5 | olavarria
# Processing Record 8 of Set 5 | sydney
# Processing Record 9 of Set 5 | atyrau
# Processing Record 10 of Set 5 | chunskiy
# Processing Record 11 of Set 5 | pouembout
# Processing Record 12 of Set 5 | moose jaw
# Processing Record 13 of Set 5 | cape town
# Processing Record 14 of Set 5 | ribeira grande
# Processing Record 15 of Set 5 | yantal
# Processing Record 16 of Set 5 | darhan
# Processing Record 17 of Set 5 | margahovit
# Processing Record 18 of Set 5 | walvis bay
# Processing Record 19 of Set 5 | lasa
# Processing Record 20 of Set 5 | jinchang
# Processing Record 21 of Set 5 | amahai
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 5 | xinan
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | kapit
# Processing Record 27 of Set 5 | yerbogachen
# Processing Record 28 of Set 5 | bjerkvik
# Processing Record 29 of Set 5 | tortoli
# Processing Record 30 of Set 5 | cayenne
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | xiongshi
# City not found. Skipping...
# Processing Record 33 of Set 5 | valle hermoso
# Processing Record 34 of Set 5 | lac-au-saumon
# Processing Record 35 of Set 5 | kastamonu
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | rawson
# Processing Record 38 of Set 5 | goderich
# Processing Record 39 of Set 5 | arkhangelos
# City not found. Skipping...
# Processing Record 40 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 5 | burlington
# Processing Record 42 of Set 5 | ust-maya
# Processing Record 43 of Set 5 | kondinskoye
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 5 | tacuarembo
# Processing Record 47 of Set 5 | ossora
# Processing Record 48 of Set 5 | mount gambier
# Processing Record 49 of Set 5 | kirakira
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | poquoson
# Processing Record 3 of Set 6 | sao benedito do rio preto
# Processing Record 4 of Set 6 | vostok
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | harboore
# Processing Record 7 of Set 6 | zhanaozen
# Processing Record 8 of Set 6 | murud
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | santo amaro da imperatriz
# Processing Record 11 of Set 6 | kamaishi
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | bridlington
# Processing Record 14 of Set 6 | sola
# Processing Record 15 of Set 6 | sechura
# Processing Record 16 of Set 6 | tazovskiy
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 6 | pervomayskiy
# Processing Record 20 of Set 6 | klaksvik
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | los llanos de aridane
# Processing Record 23 of Set 6 | denpasar
# Processing Record 24 of Set 6 | esperance
# Processing Record 25 of Set 6 | avarua
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | haines junction
# Processing Record 30 of Set 6 | madang
# Processing Record 31 of Set 6 | zhanakorgan
# Processing Record 32 of Set 6 | barcelos
# Processing Record 33 of Set 6 | camacha
# Processing Record 34 of Set 6 | chaohu
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | pizarro
# Processing Record 37 of Set 6 | clyde river
# Processing Record 38 of Set 6 | dinhata
# Processing Record 39 of Set 6 | bambanglipuro
# Processing Record 40 of Set 6 | boda
# Processing Record 41 of Set 6 | kruisfontein
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | yamada
# Processing Record 44 of Set 6 | teluknaga
# Processing Record 45 of Set 6 | kotovo
# Processing Record 46 of Set 6 | najran
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | acajutla
# Processing Record 49 of Set 6 | coahuayana
# Processing Record 50 of Set 6 | dum duma
# Processing Record 1 of Set 7 | makakilo city
# Processing Record 2 of Set 7 | mawlaik
# Processing Record 3 of Set 7 | peleduy
# Processing Record 4 of Set 7 | mae hong son
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | isla vista
# Processing Record 7 of Set 7 | lexington
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | tezu
# Processing Record 11 of Set 7 | iracoubo
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | meulaboh
# Processing Record 14 of Set 7 | tashla
# Processing Record 15 of Set 7 | bela
# Processing Record 16 of Set 7 | eureka
# Processing Record 17 of Set 7 | shumyachi
# Processing Record 18 of Set 7 | honiara
# Processing Record 19 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 21 of Set 7 | xining
# Processing Record 22 of Set 7 | maniitsoq
# Processing Record 23 of Set 7 | masty
# Processing Record 24 of Set 7 | lompoc
# Processing Record 25 of Set 7 | port blair
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | bontang
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | hammerfest
# Processing Record 31 of Set 7 | mayumba
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | khuzhir
# Processing Record 34 of Set 7 | lorengau
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | slave lake
# Processing Record 37 of Set 7 | long
# Processing Record 38 of Set 7 | tigil
# Processing Record 39 of Set 7 | zhuanghe
# Processing Record 40 of Set 7 | sarh
# Processing Record 41 of Set 7 | sapa
# Processing Record 42 of Set 7 | puerto suarez
# Processing Record 43 of Set 7 | teya
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | isabela
# Processing Record 46 of Set 7 | bayir
# Processing Record 47 of Set 7 | katha
# City not found. Skipping...
# Processing Record 48 of Set 7 | cherskiy
# Processing Record 49 of Set 7 | rocha
# Processing Record 50 of Set 7 | tevaitoa
# Processing Record 1 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 2 of Set 8 | roseburg
# Processing Record 3 of Set 8 | kudahuvadhoo
# Processing Record 4 of Set 8 | tevriz
# Processing Record 5 of Set 8 | ketchikan
# Processing Record 6 of Set 8 | bell ville
# Processing Record 7 of Set 8 | vijapur
# Processing Record 8 of Set 8 | ugoofaaru
# Processing Record 9 of Set 8 | bremervorde
# Processing Record 10 of Set 8 | broome
# Processing Record 11 of Set 8 | muros
# Processing Record 12 of Set 8 | pucallpa
# Processing Record 13 of Set 8 | skjervoy
# Processing Record 14 of Set 8 | mnogovershinnyy
# Processing Record 15 of Set 8 | ixtapa
# Processing Record 16 of Set 8 | saldanha
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | paceco
# Processing Record 20 of Set 8 | balimo
# City not found. Skipping...
# Processing Record 21 of Set 8 | fortuna
# Processing Record 22 of Set 8 | cedar city
# Processing Record 23 of Set 8 | christchurch
# Processing Record 24 of Set 8 | kristiinankaupunki
# Processing Record 25 of Set 8 | dharchula
# Processing Record 26 of Set 8 | tura
# Processing Record 27 of Set 8 | cabo san lucas
# Processing Record 28 of Set 8 | thunder bay
# Processing Record 29 of Set 8 | grand-lahou
# Processing Record 30 of Set 8 | mugur-aksy
# Processing Record 31 of Set 8 | outlook
# Processing Record 32 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 8 | shache
# Processing Record 34 of Set 8 | severo-kurilsk
# Processing Record 35 of Set 8 | loandjili
# Processing Record 36 of Set 8 | moundou
# Processing Record 37 of Set 8 | krasnovishersk
# Processing Record 38 of Set 8 | abha
# Processing Record 39 of Set 8 | ahipara
# Processing Record 40 of Set 8 | kavieng
# Processing Record 41 of Set 8 | nacala
# Processing Record 42 of Set 8 | kamenka
# Processing Record 43 of Set 8 | iwanai
# Processing Record 44 of Set 8 | la rioja
# Processing Record 45 of Set 8 | bayog
# Processing Record 46 of Set 8 | agutaya
# Processing Record 47 of Set 8 | honolulu
# Processing Record 48 of Set 8 | bara
# Processing Record 49 of Set 8 | boende
# Processing Record 50 of Set 8 | hervey bay
# Processing Record 1 of Set 9 | mhlambanyatsi
# Processing Record 2 of Set 9 | agropoli
# Processing Record 3 of Set 9 | khandbari
# Processing Record 4 of Set 9 | padang
# Processing Record 5 of Set 9 | sovetskiy
# Processing Record 6 of Set 9 | panaba
# Processing Record 7 of Set 9 | montepuez
# Processing Record 8 of Set 9 | doha
# Processing Record 9 of Set 9 | santa cruz del sur
# Processing Record 10 of Set 9 | karlskrona
# Processing Record 11 of Set 9 | guaratuba
# Processing Record 12 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 13 of Set 9 | kamiichi
# Processing Record 14 of Set 9 | auki
# Processing Record 15 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 16 of Set 9 | doliana
# Processing Record 17 of Set 9 | strezhevoy
# Processing Record 18 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 19 of Set 9 | necochea
# Processing Record 20 of Set 9 | uinskoye
# Processing Record 21 of Set 9 | taitung
# Processing Record 22 of Set 9 | chifeng
# Processing Record 23 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 9 | henties bay
# Processing Record 25 of Set 9 | maragogi
# Processing Record 26 of Set 9 | ardesen
# Processing Record 27 of Set 9 | shimoda
# Processing Record 28 of Set 9 | shibetsu
# Processing Record 29 of Set 9 | ndele
# Processing Record 30 of Set 9 | narathiwat
# Processing Record 31 of Set 9 | antofagasta
# Processing Record 32 of Set 9 | hoyanger
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | vanavara
# Processing Record 35 of Set 9 | severobaykalsk
# Processing Record 36 of Set 9 | kalmar
# Processing Record 37 of Set 9 | itaituba
# Processing Record 38 of Set 9 | pevek
# Processing Record 39 of Set 9 | manggar
# Processing Record 40 of Set 9 | saint stephen
# Processing Record 41 of Set 9 | vanino
# Processing Record 42 of Set 9 | serebryanyy bor
# Processing Record 43 of Set 9 | ostrovnoy
# Processing Record 44 of Set 9 | mezen
# Processing Record 45 of Set 9 | abu dhabi
# Processing Record 46 of Set 9 | borogontsy
# Processing Record 47 of Set 9 | hirara
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | khani
# Processing Record 50 of Set 9 | itaquyry
# Processing Record 1 of Set 10 | nanton
# Processing Record 2 of Set 10 | waipawa
# Processing Record 3 of Set 10 | tripoli
# Processing Record 4 of Set 10 | mana
# Processing Record 5 of Set 10 | jumla
# Processing Record 6 of Set 10 | khvorostyanka
# Processing Record 7 of Set 10 | cerqueira cesar
# Processing Record 8 of Set 10 | labuhan
# Processing Record 9 of Set 10 | seydisehir
# Processing Record 10 of Set 10 | yantzaza
# Processing Record 11 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 10 | ryotsu
# Processing Record 13 of Set 10 | baracoa
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | yar-sale
# Processing Record 16 of Set 10 | teguise
# Processing Record 17 of Set 10 | peniche
# Processing Record 18 of Set 10 | taoudenni
# Processing Record 19 of Set 10 | kisiwani
# Processing Record 20 of Set 10 | tual
# Processing Record 21 of Set 10 | sur
# Processing Record 22 of Set 10 | ulaangom
# Processing Record 23 of Set 10 | wanning
# Processing Record 24 of Set 10 | inuvik
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | mumford
# Processing Record 27 of Set 10 | falam
# Processing Record 28 of Set 10 | poland
# Processing Record 29 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 10 | mehamn
# Processing Record 31 of Set 10 | ilanskiy
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | khonsa
# Processing Record 34 of Set 10 | batagay
# Processing Record 35 of Set 10 | sorong
# Processing Record 36 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 37 of Set 10 | bengkulu
# Processing Record 38 of Set 10 | lavrentiya
# Processing Record 39 of Set 10 | glendive
# Processing Record 40 of Set 10 | pacific grove
# Processing Record 41 of Set 10 | ilirska bistrica
# Processing Record 42 of Set 10 | fuzhou
# Processing Record 43 of Set 10 | kisangani
# Processing Record 44 of Set 10 | chipata
# Processing Record 45 of Set 10 | puerto colombia
# Processing Record 46 of Set 10 | dudinka
# Processing Record 47 of Set 10 | aquin
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | akyab
# Processing Record 50 of Set 10 | zhuhai
# Processing Record 1 of Set 11 | woodstock
# Processing Record 2 of Set 11 | gorontalo
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | bilma
# Processing Record 5 of Set 11 | coihaique
# Processing Record 6 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 7 of Set 11 | taraz
# Processing Record 8 of Set 11 | korla
# Processing Record 9 of Set 11 | ust-nera
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | milkovo
# Processing Record 12 of Set 11 | predivinsk
# Processing Record 13 of Set 11 | chicama
# Processing Record 14 of Set 11 | gornopravdinsk
# Processing Record 15 of Set 11 | mahebourg
# Processing Record 16 of Set 11 | daru
# Processing Record 17 of Set 11 | bafq
# Processing Record 18 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 11 | lazaro cardenas
# Processing Record 20 of Set 11 | korem
# Processing Record 21 of Set 11 | bajil
# Processing Record 22 of Set 11 | coos bay
# Processing Record 23 of Set 11 | kawalu
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | makasar
# Processing Record 26 of Set 11 | mazagao
# Processing Record 27 of Set 11 | nicoya
# Processing Record 28 of Set 11 | qingdao
# Processing Record 29 of Set 11 | glomfjord
# Processing Record 30 of Set 11 | yoichi
# Processing Record 31 of Set 11 | hovd
# Processing Record 32 of Set 11 | emba
# Processing Record 33 of Set 11 | kerema
# Processing Record 34 of Set 11 | naryan-mar
# Processing Record 35 of Set 11 | ivanava
# Processing Record 36 of Set 11 | gravdal
# Processing Record 37 of Set 11 | flin flon
# Processing Record 38 of Set 11 | huarmey
# Processing Record 39 of Set 11 | san matias
# Processing Record 40 of Set 11 | yeppoon
# Processing Record 41 of Set 11 | mayo
# Processing Record 42 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 11 | praia
# Processing Record 44 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | watertown
# Processing Record 46 of Set 11 | ouidah
# Processing Record 47 of Set 11 | te anau
# Processing Record 48 of Set 11 | zhigalovo
# Processing Record 49 of Set 11 | xiongzhou
# Processing Record 50 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 1 of Set 12 | bonthe
# Processing Record 2 of Set 12 | verkhoyansk
# Processing Record 3 of Set 12 | wiarton
# Processing Record 4 of Set 12 | korhogo
# Processing Record 5 of Set 12 | carman
# Processing Record 6 of Set 12 | jacareacanga
# Processing Record 7 of Set 12 | sobradinho
# Processing Record 8 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 9 of Set 12 | mackay
# Processing Record 10 of Set 12 | portland
# Processing Record 11 of Set 12 | la orilla
# Processing Record 12 of Set 12 | farrukhnagar
# Processing Record 13 of Set 12 | ajra
# Processing Record 14 of Set 12 | kumluca
# Processing Record 15 of Set 12 | tandil
# Processing Record 16 of Set 12 | provideniya
# Processing Record 17 of Set 12 | moses lake
# Processing Record 18 of Set 12 | dhidhdhoo
# Processing Record 19 of Set 12 | quthing
# Processing Record 20 of Set 12 | malgobek
# Processing Record 21 of Set 12 | jinxiang
# Processing Record 22 of Set 12 | finschhafen
# Processing Record 23 of Set 12 | bhakkar
# Processing Record 24 of Set 12 | sinegorye
# Processing Record 25 of Set 12 | adrar
# Processing Record 26 of Set 12 | stokmarknes
# Processing Record 27 of Set 12 | buala
# Processing Record 28 of Set 12 | avera
# Processing Record 29 of Set 12 | miles city
# Processing Record 30 of Set 12 | pierre
# Processing Record 31 of Set 12 | easton
# Processing Record 32 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 12 | santa isabel do rio negro
# Processing Record 34 of Set 12 | kalyazin
# Processing Record 35 of Set 12 | komsomolskiy
# Processing Record 36 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 12 | anolaima
# Processing Record 38 of Set 12 | ostuacan
# Processing Record 39 of Set 12 | omsukchan
# Processing Record 40 of Set 12 | pirovskoye
# Processing Record 41 of Set 12 | lichinga
# Processing Record 42 of Set 12 | basco
# Processing Record 43 of Set 12 | kaeo
# Processing Record 44 of Set 12 | mahibadhoo
# Processing Record 45 of Set 12 | nantucket
# Processing Record 46 of Set 12 | longjiang
# Processing Record 47 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 48 of Set 12 | remedios
# Processing Record 49 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 50 of Set 12 | novovasylivka
# Processing Record 1 of Set 13 | huimanguillo
# Processing Record 2 of Set 13 | hermosillo
# Processing Record 3 of Set 13 | tyrma
# Processing Record 4 of Set 13 | washington
# Processing Record 5 of Set 13 | dalvik
# Processing Record 6 of Set 13 | xichang
# Processing Record 7 of Set 13 | gawler
# Processing Record 8 of Set 13 | yenagoa
# Processing Record 9 of Set 13 | bud
# Processing Record 10 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | miravci
# Processing Record 13 of Set 13 | kutoarjo
# Processing Record 14 of Set 13 | tecoman
# Processing Record 15 of Set 13 | san javier
# Processing Record 16 of Set 13 | moerai
# Processing Record 17 of Set 13 | ninghai
# Processing Record 18 of Set 13 | chingola
# Processing Record 19 of Set 13 | mogadishu
# Processing Record 20 of Set 13 | oum hadjer
# Processing Record 21 of Set 13 | harper
# Processing Record 22 of Set 13 | oksfjord
# Processing Record 23 of Set 13 | saint-augustin
# Processing Record 24 of Set 13 | khowai
# Processing Record 25 of Set 13 | faanui
# Processing Record 26 of Set 13 | sapele
# Processing Record 27 of Set 13 | dubbo
# Processing Record 28 of Set 13 | vila
# Processing Record 29 of Set 13 | akureyri
# Processing Record 30 of Set 13 | sungaipenuh
# Processing Record 31 of Set 13 | innisfail
# Processing Record 32 of Set 13 | tieling
# Processing Record 33 of Set 13 | maceio
# Processing Record 34 of Set 13 | aqtobe
# Processing Record 35 of Set 13 | kourou
# Processing Record 36 of Set 13 | atar
# Processing Record 37 of Set 13 | zhatay
# Processing Record 38 of Set 13 | cork
# Processing Record 39 of Set 13 | burica
# City not found. Skipping...
# Processing Record 40 of Set 13 | ballina
# Processing Record 41 of Set 13 | hami
# Processing Record 42 of Set 13 | fayaoue
# Processing Record 43 of Set 13 | talnakh
# Processing Record 44 of Set 13 | lulea
# Processing Record 45 of Set 13 | porto novo
# Processing Record 46 of Set 13 | panguna
# Processing Record 47 of Set 13 | shakawe
# Processing Record 48 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 13 | axim
# Processing Record 50 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 14 | west bay
# Processing Record 2 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 14 | timiryazevskoye
# Processing Record 4 of Set 14 | anloga
# Processing Record 5 of Set 14 | breves
# Processing Record 6 of Set 14 | umkomaas
# Processing Record 7 of Set 14 | punta gorda
# Processing Record 8 of Set 14 | palora
# Processing Record 9 of Set 14 | lagos
# Processing Record 10 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 14 | stilfontein
# Processing Record 12 of Set 14 | nador
# Processing Record 13 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 14 | vila do maio
# Processing Record 15 of Set 14 | alta floresta
# Processing Record 16 of Set 14 | nyrob
# Processing Record 17 of Set 14 | sharjah
# Processing Record 18 of Set 14 | kargasok
# Processing Record 19 of Set 14 | acapulco
# Processing Record 20 of Set 14 | kungurtug
# Processing Record 21 of Set 14 | selma
# Processing Record 22 of Set 14 | wangaratta
# Processing Record 23 of Set 14 | inhambane
# Processing Record 24 of Set 14 | salinopolis
# Processing Record 25 of Set 14 | ulaanbaatar
# Processing Record 26 of Set 14 | asfi
# Processing Record 27 of Set 14 | kibakwe
# Processing Record 28 of Set 14 | jiangyou
# Processing Record 29 of Set 14 | pindi gheb
# Processing Record 30 of Set 14 | dhankuta
# Processing Record 31 of Set 14 | hamadan
# Processing Record 32 of Set 14 | newport
# Processing Record 33 of Set 14 | cabedelo
# Processing Record 34 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 14 | hare bay
# Processing Record 36 of Set 14 | erdenet
# Processing Record 37 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 38 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 14 | okhotsk
# Processing Record 40 of Set 14 | taikang
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | bathsheba
# Processing Record 43 of Set 14 | luanda
# Processing Record 44 of Set 14 | berdigestyakh
# Processing Record 45 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 14 | vytegra
# Processing Record 47 of Set 14 | silway
# City not found. Skipping...
# Processing Record 48 of Set 14 | cockburn town
# Processing Record 49 of Set 14 | partizanskoye
# Processing Record 50 of Set 14 | turkmenabat
# Processing Record 1 of Set 15 | peace river
# Processing Record 2 of Set 15 | na wa
# Processing Record 3 of Set 15 | kindersley
# Processing Record 4 of Set 15 | maldonado
# Processing Record 5 of Set 15 | talakan
# Processing Record 6 of Set 15 | mvuma
# Processing Record 7 of Set 15 | eskil
# Processing Record 8 of Set 15 | cap malheureux
# Processing Record 9 of Set 15 | prnjavor
# Processing Record 10 of Set 15 | hof
# Processing Record 11 of Set 15 | denizli
# Processing Record 12 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 15 | trapani
# Processing Record 14 of Set 15 | prince rupert
# Processing Record 15 of Set 15 | nhulunbuy
# Processing Record 16 of Set 15 | severo-yeniseyskiy
# Processing Record 17 of Set 15 | sorata
# Processing Record 18 of Set 15 | yumen
# Processing Record 19 of Set 15 | dongkan
# Processing Record 20 of Set 15 | tucumcari
# Processing Record 21 of Set 15 | yakshur-bodya
# City not found. Skipping...
# Processing Record 22 of Set 15 | stolbishche
# Processing Record 23 of Set 15 | bintulu
# Processing Record 24 of Set 15 | batticaloa
# Processing Record 25 of Set 15 | palana
# Processing Record 26 of Set 15 | saint anthony
# Processing Record 27 of Set 15 | nouakchott
# Processing Record 28 of Set 15 | slavyanka
# Processing Record 29 of Set 15 | sorland
# Processing Record 30 of Set 15 | belmonte
# Processing Record 31 of Set 15 | mindelo
# Processing Record 32 of Set 15 | rawah
# Processing Record 33 of Set 15 | kawardha
# Processing Record 34 of Set 15 | suez
# Processing Record 35 of Set 15 | praia da vitoria
# Processing Record 36 of Set 15 | dabhol
# Processing Record 37 of Set 15 | morro da fumaca
# Processing Record 38 of Set 15 | tsiroanomandidy
# Processing Record 39 of Set 15 | buwenge
# Processing Record 40 of Set 15 | ferme-neuve
# Processing Record 41 of Set 15 | japura
# Processing Record 42 of Set 15 | alto araguaia
# Processing Record 43 of Set 15 | pipri
# Processing Record 44 of Set 15 | palimbang
# Processing Record 45 of Set 15 | taldan
# Processing Record 46 of Set 15 | frankfort
# Processing Record 47 of Set 15 | rock sound
# Processing Record 48 of Set 15 | surt
# Processing Record 49 of Set 15 | la paz
# Processing Record 50 of Set 15 | katangli
# Processing Record 1 of Set 16 | karatau
# Processing Record 2 of Set 16 | kilindoni
# Processing Record 3 of Set 16 | panzhihua
# Processing Record 4 of Set 16 | chernyshevskiy
# Processing Record 5 of Set 16 | srivardhan
# Processing Record 6 of Set 16 | tessalit
# Processing Record 7 of Set 16 | sarahan
# Processing Record 8 of Set 16 | gashua
# Processing Record 9 of Set 16 | stornoway
# Processing Record 10 of Set 16 | pangai
# Processing Record 11 of Set 16 | yefimovskiy
# City not found. Skipping...
# Processing Record 12 of Set 16 | dongning
# Processing Record 13 of Set 16 | appleton
# Processing Record 14 of Set 16 | nouadhibou
# Processing Record 15 of Set 16 | dzhebariki-khaya
# Processing Record 16 of Set 16 | whitehorse
# Processing Record 17 of Set 16 | aasiaat
# Processing Record 18 of Set 16 | sibolga
# Processing Record 19 of Set 16 | bilaua
# City not found. Skipping...
# Processing Record 20 of Set 16 | maturin
# Processing Record 21 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 16 | eganville
# Processing Record 23 of Set 16 | balagansk
# Processing Record 24 of Set 16 | esna
# Processing Record 25 of Set 16 | mandera
# Processing Record 26 of Set 16 | mochudi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
#converting array in dataframe
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0        Dingle      PH  2020-08-30 18:03:53  11.00  122.67     77.56
# 1   Qinhuangdao      CN  2020-08-30 18:03:53  39.93  119.59     69.67
# 2         Tawau      MY  2020-08-30 18:03:53   4.25  117.89     77.00
# 3         Arman      RU  2020-08-30 18:03:54  59.70  150.17     44.80
# 4        Albany      US  2020-08-30 18:03:02  42.60  -73.97     71.01
# 5      Tasiilaq      GL  2020-08-30 18:02:48  65.61  -37.64     44.60
# 6       Pahrump      US  2020-08-30 18:03:55  36.21 -115.98     93.99
# 7  Ponta Do Sol      PT  2020-08-30 18:03:55  32.67  -17.10     75.00
# 8       Mataura      NZ  2020-08-30 18:03:55 -46.19  168.86     45.00
# 9         Kapaa      US  2020-08-30 17:59:49  22.08 -159.32     79.00
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        84         100        5.10   overcast clouds
# 1        84          13        1.25        few clouds
# 2        88          20        3.36        few clouds
# 3        61           0        4.97         clear sky
# 4        43          22        4.00        few clouds
# 5        70         100        2.24   overcast clouds
# 6         9           0        3.00         clear sky
# 7        42           5        5.17         clear sky
# 8        72          47       11.01  scattered clouds
# 9        74          40       16.11  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
